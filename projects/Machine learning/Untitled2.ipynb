# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"F:\jupyter py\heartattack_prediction_with_nulls.csv")
data
# Display the first few rows
# Out:
#        Age   Sex ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0       68  Male       Typical      135.0        265.0          0
# 1       58  Male       Typical       97.0        288.0          1
# 2       44  Male       Typical       95.0        185.0          1
# 3       72  Male  Asymptomatic      142.0        257.0          0
# 4       37  Male       Typical      153.0        181.0          0
# ...    ...   ...           ...        ...          ...        ...
# 19995   56  Male   Non-Anginal      130.0        190.0          1
# 19996   39  Male       Typical      153.0        154.0          1
# 19997   78  Male  Asymptomatic      131.0        283.0          1
# 19998   44  Male  Asymptomatic      133.0        225.0          0
# 19999   48  Male   Non-Anginal      120.0        195.0          0
#
#         RestingECG  MaxHR ExerciseAngina  HeartDisease
# 0               ST    137            Yes             0
# 1      Hypertrophy    139            Yes             0
# ...

# %%
data.head()
# Out:
#    Age   Sex ChestPainType  RestingBP  Cholesterol  FastingBS   RestingECG  \
# 0   68  Male       Typical      135.0        265.0          0           ST
# 1   58  Male       Typical       97.0        288.0          1  Hypertrophy
# 2   44  Male       Typical       95.0        185.0          1           ST
# 3   72  Male  Asymptomatic      142.0        257.0          0       Normal
# 4   37  Male       Typical      153.0        181.0          0           ST
#
#    MaxHR ExerciseAngina  HeartDisease
# 0    137            Yes             0
# 1    139            Yes             0
# 2    109            Yes             0
# 3     78            Yes             1
# 4    133            Yes             0

# %%
data.describe()
# Out:
#                 Age     RestingBP   Cholesterol     FastingBS         MaxHR  \
# count  20000.000000  19536.000000  19657.000000  20000.000000  20000.000000
# mean      54.437650    134.239762    224.229842      0.492550    129.510250
# std       14.361327     26.150314     43.363352      0.499957     40.329296
# min       30.000000     90.000000    150.000000      0.000000     60.000000
# 25%       42.000000    112.000000    186.000000      0.000000     94.000000
# 50%       54.000000    134.000000    225.000000      0.000000    130.000000
# 75%       67.000000    157.000000    261.000000      1.000000    164.000000
# max       79.000000    179.000000    299.000000      1.000000    199.000000
#
#        HeartDisease
# count  20000.000000
# mean       0.408600
# std        0.491587
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
data.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP         float64
# Cholesterol       float64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# HeartDisease        int64
# dtype: object

# %%
data.shape
# Out:
# (20000, 10)

# %%
df=data.drop_duplicates()
df
# Out:
#        Age   Sex ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0       68  Male       Typical      135.0        265.0          0
# 1       58  Male       Typical       97.0        288.0          1
# 2       44  Male       Typical       95.0        185.0          1
# 3       72  Male  Asymptomatic      142.0        257.0          0
# 4       37  Male       Typical      153.0        181.0          0
# ...    ...   ...           ...        ...          ...        ...
# 19995   56  Male   Non-Anginal      130.0        190.0          1
# 19996   39  Male       Typical      153.0        154.0          1
# 19997   78  Male  Asymptomatic      131.0        283.0          1
# 19998   44  Male  Asymptomatic      133.0        225.0          0
# 19999   48  Male   Non-Anginal      120.0        195.0          0
#
#         RestingECG  MaxHR ExerciseAngina  HeartDisease
# 0               ST    137            Yes             0
# 1      Hypertrophy    139            Yes             0
# ...

# %%
data.isnull().sum()
# Out:
# Age                 0
# Sex                 0
# ChestPainType       0
# RestingBP         464
# Cholesterol       343
# FastingBS           0
# RestingECG          0
# MaxHR               0
# ExerciseAngina      0
# HeartDisease        0
# dtype: int64

# %%
df['RestingBP'].fillna(df['RestingBP'].median(), inplace=True)
# Out:
# C:\Users\Adarsh\AppData\Local\Temp\ipykernel_6212\3501749298.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RestingBP'].fillna(df['RestingBP'].median(), inplace=True)

# %%
df['Cholesterol'].fillna(df['Cholesterol'].median(), inplace=True)
# Out:
# C:\Users\Adarsh\AppData\Local\Temp\ipykernel_6212\4131661491.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cholesterol'].fillna(df['Cholesterol'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# HeartDisease      0
# dtype: int64

# %%
print("number of people who take loan as group by marital_status:")
print(df['ChestPainType'].value_counts())
sns.countplot(x='ChestPainType', data=df)
plt.show()
# Out:
# number of people who take loan as group by marital_status:
# ChestPainType
# Asymptomatic    5134
# Typical         5118
# Non-Anginal     4896
# Atypical        4852
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data['Age'], kde=True, bins=30, color='blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#we will see the number of people who take loan as group by gender
print("number of people who has HeartDisease by gender:")
print(df['Sex'].value_counts())
sns.countplot(x='Sex', data=df)
# Out:
# number of people who has HeartDisease by gender:
# Sex
# Male      11662
# Female     8338
# Name: count, dtype: int64
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df_num=df.select_dtypes(['int','float'])
df_num
# Out:
#        Age  RestingBP  Cholesterol  FastingBS  MaxHR  HeartDisease
# 0       68      135.0        265.0          0    137             0
# 1       58       97.0        288.0          1    139             0
# 2       44       95.0        185.0          1    109             0
# 3       72      142.0        257.0          0     78             1
# 4       37      153.0        181.0          0    133             0
# ...    ...        ...          ...        ...    ...           ...
# 19995   56      130.0        190.0          1    173             0
# 19996   39      153.0        154.0          1     74             0
# 19997   78      131.0        283.0          1    103             0
# 19998   44      133.0        225.0          0    154             0
# 19999   48      120.0        195.0          0    164             0
#
# [20000 rows x 6 columns]

# %%
df_cat1=df.select_dtypes(['object'])
df_cat1
# Out:
#         Sex ChestPainType   RestingECG ExerciseAngina
# 0      Male       Typical           ST            Yes
# 1      Male       Typical  Hypertrophy            Yes
# 2      Male       Typical           ST            Yes
# 3      Male  Asymptomatic       Normal            Yes
# 4      Male       Typical           ST            Yes
# ...     ...           ...          ...            ...
# 19995  Male   Non-Anginal  Hypertrophy            Yes
# 19996  Male       Typical       Normal            Yes
# 19997  Male  Asymptomatic       Normal             No
# 19998  Male  Asymptomatic       Normal            Yes
# 19999  Male   Non-Anginal       Normal             No
#
# [20000 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in df_cat1:
    df[i]=le.fit_transform(df[i])
df
# Out:
#        Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0       68    1              3      135.0        265.0          0           2
# 1       58    1              3       97.0        288.0          1           0
# 2       44    1              3       95.0        185.0          1           2
# 3       72    1              0      142.0        257.0          0           1
# 4       37    1              3      153.0        181.0          0           2
# ...    ...  ...            ...        ...          ...        ...         ...
# 19995   56    1              2      130.0        190.0          1           0
# 19996   39    1              3      153.0        154.0          1           1
# 19997   78    1              0      131.0        283.0          1           1
# 19998   44    1              0      133.0        225.0          0           1
# 19999   48    1              2      120.0        195.0          0           1
#
# ...

# %%
features = df.iloc[:,:-1]
features
# Out:
#        Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0       68    1              3      135.0        265.0          0           2
# 1       58    1              3       97.0        288.0          1           0
# 2       44    1              3       95.0        185.0          1           2
# 3       72    1              0      142.0        257.0          0           1
# 4       37    1              3      153.0        181.0          0           2
# ...    ...  ...            ...        ...          ...        ...         ...
# 19995   56    1              2      130.0        190.0          1           0
# 19996   39    1              3      153.0        154.0          1           1
# 19997   78    1              0      131.0        283.0          1           1
# 19998   44    1              0      133.0        225.0          0           1
# 19999   48    1              2      120.0        195.0          0           1
#
#        MaxHR  ExerciseAngina
# ...

# %%
target = df.iloc[:,-1]
target
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 19995    0
# 19996    0
# 19997    0
# 19998    0
# 19999    0
# Name: HeartDisease, Length: 20000, dtype: int64

# %%
# 1. Correlation Heatmap
plt.figure(figsize=(10, 8))
correlation = df.corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Initialize and train
target_counts = target.value_counts()
plt.figure(figsize=(6, 4))
target_counts.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Count of Target Values')
plt.xlabel('Target (0 = No Heart Attack, 1 = Heart Attack)')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
x=features
y=target
x
# Out:
#        Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0       68    1              3      135.0        265.0          0           2
# 1       58    1              3       97.0        288.0          1           0
# 2       44    1              3       95.0        185.0          1           2
# 3       72    1              0      142.0        257.0          0           1
# 4       37    1              3      153.0        181.0          0           2
# ...    ...  ...            ...        ...          ...        ...         ...
# 19995   56    1              2      130.0        190.0          1           0
# 19996   39    1              3      153.0        154.0          1           1
# 19997   78    1              0      131.0        283.0          1           1
# 19998   44    1              0      133.0        225.0          0           1
# 19999   48    1              2      120.0        195.0          0           1
#
#        MaxHR  ExerciseAngina
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 19995    0
# 19996    0
# 19997    0
# 19998    0
# 19999    0
# Name: HeartDisease, Length: 20000, dtype: int64

# %%
x
# Out:
#        Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0       68    1              3      135.0        265.0          0           2
# 1       58    1              3       97.0        288.0          1           0
# 2       44    1              3       95.0        185.0          1           2
# 3       72    1              0      142.0        257.0          0           1
# 4       37    1              3      153.0        181.0          0           2
# ...    ...  ...            ...        ...          ...        ...         ...
# 19995   56    1              2      130.0        190.0          1           0
# 19996   39    1              3      153.0        154.0          1           1
# 19997   78    1              0      131.0        283.0          1           1
# 19998   44    1              0      133.0        225.0          0           1
# 19999   48    1              2      120.0        195.0          0           1
#
#        MaxHR  ExerciseAngina
# ...

# %%
# Splitting the Data into Training set and Testing Set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((14000, 9), (6000, 9), (14000,), (6000,))

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler = MinMaxScaler(feature_range=(0, 1)) # MinMaxScaler to scale features to a range of [0, 1]
mmscaler
# Out:
# MinMaxScaler()

# %%
X_train = mmscaler.fit_transform(X_train)
X_train
# Out:
# array([[0.34693878, 1.        , 1.        , ..., 0.        , 0.58992806,
#         1.        ],
#        [0.2244898 , 0.        , 0.66666667, ..., 1.        , 0.12230216,
#         1.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.65467626,
#         0.        ],
#        ...,
#        [0.79591837, 0.        , 1.        , ..., 0.        , 0.28057554,
#         1.        ],
#        [0.83673469, 1.        , 0.        , ..., 0.        , 0.64748201,
#         0.        ],
#        [0.57142857, 0.        , 0.66666667, ..., 1.        , 0.39568345,
#         0.        ]])

# %%
X_test = mmscaler.fit_transform(X_test)
X_test
# Out:
# array([[0.34693878, 0.        , 1.        , ..., 0.5       , 0.12230216,
#         1.        ],
#        [0.14285714, 0.        , 1.        , ..., 1.        , 0.32374101,
#         1.        ],
#        [0.93877551, 1.        , 1.        , ..., 0.        , 0.38848921,
#         0.        ],
#        ...,
#        [0.95918367, 1.        , 1.        , ..., 0.        , 0.70503597,
#         1.        ],
#        [0.30612245, 0.        , 0.        , ..., 0.5       , 0.23021583,
#         1.        ],
#        [0.18367347, 0.        , 1.        , ..., 1.        , 0.52517986,
#         1.        ]])

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

print("Accuracy Score:", accuracy_score(y_test, y_pred))
print('Accuracy of LogisticRegression:', round(accuracy_score(y_test, y_pred),2)*100,"%")
# Out:
# Accuracy Score: 0.5488333333333333
# Accuracy of LogisticRegression: 55.00000000000001 %

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model = LogisticRegression(solver="sag")

# Train the model
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Evaluate the model
print('Accuracy of LogisticRegression:', round(accuracy_score(y_test, y_pred),2)*100,"%")
# Out:
# Accuracy of LogisticRegression: 59.0 %

# %%
from sklearn.tree import DecisionTreeClassifier

# Same preprocessing steps as above...

# Create decision tree model
model = DecisionTreeClassifier(max_depth=7,min_samples_leaf=5,random_state=42)

# Train the model
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Evaluate the model
print('Accuracy of DecisionTreeClassifier :', accuracy_score(y_test, y_pred))
print('Accuracy of LogisticRegression:', round(accuracy_score(y_test, y_pred),2)*100,"%")
# Out:
# Accuracy of DecisionTreeClassifier : 0.567
# Accuracy of LogisticRegression: 56.99999999999999 %

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
print("Acuuracy of Support Vector Machine: ", accuracy_score(y_test, y_pred))
print('Accuracy of LogisticRegression:', round(accuracy_score(y_test, y_pred),2)*100,"%")
# Out:
# Acuuracy of Support Vector Machine:  0.5886666666666667
# Accuracy of LogisticRegression: 59.0 %

# %%
from sklearn.neighbors import KNeighborsRegressor 
# K-Nearest Neighbors regression model (based on proximity of data points)
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
y_pred6 = knn.predict(X_test)
r2_7 = r2_score(y_test, y_pred6)
print("R-squared:", r2_7)
rounded_r2 = round(r2_7, 4)
print("R-squared (rounded):", rounded_r2*100)
# Out:
# R-squared: -0.2288298143759946
# R-squared (rounded): -22.88
